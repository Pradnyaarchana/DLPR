# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from keras.models import Sequential 
from keras.datasets import mnist
import random

# %%
(x_train,y_train), (x_test,y_test)= mnist.load_data()
x_train=x_train/255
x_test=x_test/255

# %%
import keras
model=Sequential()
model.add(keras.layers.Flatten(input_shape=(28,28)))
model.add(keras.layers.Dense(130,activation='relu'))
model.add(keras.layers.Dense(10,activation='softmax'))

# %%
model.compile(optimizer='sgd', loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
H=model.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.7415 - loss: 1.0043 - val_accuracy: 0.9048 - val_loss: 0.3521
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9024 - loss: 0.3530 - val_accuracy: 0.9167 - val_loss: 0.2920
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9175 - loss: 0.2954 - val_accuracy: 0.9268 - val_loss: 0.2588
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9275 - loss: 0.2585 - val_accuracy: 0.9318 - val_loss: 0.2378
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9307 - loss: 0.2438 - val_accuracy: 0.9360 - val_loss: 0.2204
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9376 - loss: 0.2203 - val_accuracy: 0.9416 - val_loss: 0.2036
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9427 - loss: 0.2037 - val_accuracy: 0.9437 - val_loss: 0.1937
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9470 - loss: 0.1897 - val_accuracy: 0.9481 - val_loss: 0.1805
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9505 - loss: 0.1787 - val_accuracy: 0.9502 - val_loss: 0.1724
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 4ms/step - accuracy: 0.9537 - loss: 0.1675 - val_accuracy: 0.9517 - val_loss: 0.1646

# %%
test_loss,test_acc=model.evaluate(x_test,y_test)
print("Loss=%.3f" %test_loss)
print("Accuracy=%.3f"%test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9428 - loss: 0.1911
# Loss=0.165
# Accuracy=0.952

# %%
n=random.randint(0,9999)

plt.imshow(x_test[n])
plt.show()
prediction=model.predict(x_test)
print("The handwritten number in the image is %d" %np.argmax(prediction[n]))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# The handwritten number in the image is 2

# %%
plt.plot(H.history['loss'], label='train_loss')
plt.plot(H.history['val_loss'], label='val_loss')
plt.plot(H.history['accuracy'], label='train_acc')
plt.plot(H.history['val_accuracy'], label='val_acc')
plt.title('Training Loss and Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss/Accuracy')
plt.legend()
plt.grid(True)
plt.show()
